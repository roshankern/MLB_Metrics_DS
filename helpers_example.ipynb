# %% [markdown]
# # MLB Metrics Helpers Examples
#
# Example uses for helper functions in mlb_metrics_helpers.py

# %% [markdown]
# ### Import libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import mlb_metrics_helpers

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Create scatter plot of pitch locations, colored by pitch type

# %%
# get pitcher data
aardsma_id = mlb_metrics_helpers.player_id("Aardsma", "David")
aardsma_general_stats = mlb_metrics_helpers.player_general_metrics(
    aardsma_id, timeline_type="career"
)
aardsma_timeline = mlb_metrics_helpers.parse_career_timeline(aardsma_general_stats)
aardsma_specific_stats = mlb_metrics_helpers.player_specific_metrics(
    aardsma_id,
    metric_type="pitching",
    start_dt=aardsma_timeline[0],
    end_dt=aardsma_timeline[1],
)

aardsma_specific_stats
# Out:
# Gathering player lookup table. This may take a moment.
# Gathering Player Data
#      pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0            FF  2010-04-05           96.0          -2.04           6.29
# 1            FF  2010-04-05           95.4          -1.94           6.31
# 2            FF  2010-04-05           95.5          -2.06           6.45
# 3            FF  2010-04-05           95.4          -2.09           6.41
# 4            FF  2010-04-05           94.3          -1.88           6.31
# ...         ...         ...            ...            ...            ...
# 2320         FF  2010-04-10           93.0          -2.26           6.35
# 2321         SL  2010-04-10           85.5          -1.87           6.42
# 2322         FF  2010-04-10           91.8          -2.21           6.37
# 2323         FF  2010-04-10           92.1          -2.21           6.36
# 2324         FF  2010-04-10           91.5          -2.27           6.47
#
#          player_name  batter  pitcher     events      description  ...  \
# 0     Aardsma, David  459941   430911  strikeout    called_strike  ...
# 1     Aardsma, David  459941   430911        NaN             foul  ...
# 2     Aardsma, David  459941   430911        NaN             ball  ...
# 3     Aardsma, David  459941   430911        NaN             ball  ...
# 4     Aardsma, David  459941   430911        NaN             foul  ...
# ...              ...     ...      ...        ...              ...  ...
# 2320  Aardsma, David  462101   430911        NaN    called_strike  ...
# 2321  Aardsma, David  461815   430911  strikeout  swinging_strike  ...
# 2322  Aardsma, David  461815   430911        NaN    called_strike  ...
# 2323  Aardsma, David  461815   430911        NaN    called_strike  ...
# 2324  Aardsma, David  461815   430911        NaN             ball  ...
#
#       fld_score  post_away_score  post_home_score  post_bat_score  \
# 0             5                5                3               3
# 1             5                5                3               3
# 2             5                5                3               3
# 3             5                5                3               3
# 4             5                5                3               3
# ...         ...              ...              ...             ...
# 2320          4                4                3               3
# 2321          4                4                3               3
# 2322          4                4                3               3
# 2323          4                4                3               3
# 2324          4                4                3               3
#
#       post_fld_score if_fielding_alignment of_fielding_alignment spin_axis  \
# 0                  5                   NaN                   NaN       NaN
# 1                  5                   NaN                   NaN       NaN
# 2                  5                   NaN                   NaN       NaN
# 3                  5                   NaN                   NaN       NaN
# 4                  5                   NaN                   NaN       NaN
# ...              ...                   ...                   ...       ...
# 2320               4                   NaN                   NaN       NaN
# 2321               4                   NaN                   NaN       NaN
# 2322               4                   NaN                   NaN       NaN
# 2323               4                   NaN                   NaN       NaN
# 2324               4                   NaN                   NaN       NaN
#
#      delta_home_win_exp delta_run_exp
# 0                -0.014        -0.126
# 1                 0.000         0.000
# 2                 0.000         0.038
# 3                 0.000         0.018
# 4                 0.000        -0.024
# ...                 ...           ...
# 2320              0.000        -0.023
# 2321             -0.086        -0.167
# 2322              0.000        -0.058
# 2323              0.000        -0.042
# 2324              0.000         0.034
#
# [4966 rows x 92 columns]

# %%
# get location data for different pitches crossing the plate
aardsma_plate_crossing_metrics = aardsma_specific_stats[
        ~aardsma_specific_stats["plate_x"].isna()
        & ~aardsma_specific_stats["plate_z"].isna()
    ]
pitch_name_locations = aardsma_plate_crossing_metrics[['pitch_name', 'plate_x', 'plate_z']]

# Set up the plot
plt.figure(figsize=(8, 6))

# Create scatter plot
sns.scatterplot(data=pitch_name_locations, x="plate_x", y="plate_z", hue="pitch_name", s=100, alpha=0.5)

# Customize the axes
plt.axvline(x=-0.71, color='gray', linestyle='--')  # left bound of strike zone (17 inches / 2)
plt.axvline(x=0.71, color='gray', linestyle='--')  # right bound of strike zone (17 inches / 2)

# Add labels and legend
plt.title("Scatter Plot of Types of Pitches Crossing Plate")
plt.xlabel("Horizontal Position (feet)")
plt.ylabel("Vertical Position (feet)")
plt.legend(title="Pitch Name")

# Show plot
plt.show()

# %% [markdown]
# ### Create scatter plot of pitched balls, colored by batting event

# %%
# get batter data
judge_id = mlb_metrics_helpers.player_id("Judge", "Aaron")
judge_general_stats = mlb_metrics_helpers.player_general_metrics(judge_id, timeline_type="career")
judge_timeline = mlb_metrics_helpers.parse_career_timeline(judge_general_stats)
judge_specific_stats = mlb_metrics_helpers.player_specific_metrics(
    judge_id,
    metric_type="batting",
    start_dt=judge_timeline[0],
    end_dt=judge_timeline[1],
)

judge_specific_stats
# Out:
# Gathering Player Data
#      pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0            CU  2022-08-12           77.0          -2.27           5.63
# 1            CU  2022-08-12           76.8          -2.09           5.59
# 2            FC  2022-08-12           89.3          -2.27           5.43
# 3            FS  2022-08-12           86.5          -2.38           5.41
# 4            FF  2022-08-12           92.9          -2.36           5.40
# ...         ...         ...            ...            ...            ...
# 3128         SL  2022-08-13           86.8          -2.23           5.86
# 3129         SI  2022-08-13           92.5          -2.87           3.85
# 3130         FF  2022-08-13           96.1          -1.98           5.96
# 3131         SL  2022-08-13           83.1          -3.15           3.78
# 3132         SL  2022-08-13           82.8          -3.08           3.75
#
#        player_name  batter  pitcher     events      description  ...  \
# 0     Judge, Aaron  592450   543135  strikeout  swinging_strike  ...
# 1     Judge, Aaron  592450   543135        NaN             ball  ...
# 2     Judge, Aaron  592450   543135        NaN             ball  ...
# 3     Judge, Aaron  592450   543135        NaN  swinging_strike  ...
# 4     Judge, Aaron  592450   543135        NaN    called_strike  ...
# ...            ...     ...      ...        ...              ...  ...
# 3128  Judge, Aaron  592450   676710        NaN             ball  ...
# 3129  Judge, Aaron  592450   670167        NaN             foul  ...
# 3130  Judge, Aaron  592450   676710        NaN    called_strike  ...
# 3131  Judge, Aaron  592450   670167        NaN             ball  ...
# 3132  Judge, Aaron  592450   670167        NaN             ball  ...
#
#       fld_score  post_away_score  post_home_score  post_bat_score  \
# 0             1                2                1               2
# 1             1                2                1               2
# 2             1                2                1               2
# 3             1                2                1               2
# 4             1                2                1               2
# ...         ...              ...              ...             ...
# 3128          0                0                0               0
# 3129          2                2                2               2
# 3130          0                0                0               0
# 3131          2                2                2               2
# 3132          2                2                2               2
#
#       post_fld_score if_fielding_alignment of_fielding_alignment spin_axis  \
# 0                  1              Standard              Standard      41.0
# 1                  1              Standard              Standard      47.0
# 2                  1              Standard              Standard     187.0
# 3                  1              Standard              Standard     238.0
# 4                  1              Standard              Standard     223.0
# ...              ...                   ...                   ...       ...
# 3128               0         Infield shift              Standard     110.0
# 3129               2              Standard              Standard     267.0
# 3130               0         Infield shift              Standard     210.0
# 3131               2              Standard              Standard      74.0
# 3132               2              Standard              Standard      79.0
#
#      delta_home_win_exp delta_run_exp
# 0                 0.023        -0.195
# 1                 0.000         0.037
# 2                 0.000         0.017
# 3                 0.000        -0.046
# 4                 0.000        -0.034
# ...                 ...           ...
# 3128              0.000         0.016
# 3129              0.000        -0.042
# 3130              0.000        -0.024
# 3131              0.000         0.044
# 3132              0.000         0.023
#
# [17122 rows x 92 columns]

# %%
# get location data for batting events crossing the plate
judge_plate_crossing_metrics = judge_specific_stats[
        ~judge_specific_stats["plate_x"].isna()
        & ~judge_specific_stats["plate_z"].isna()
    ]
description_locations = judge_plate_crossing_metrics[['description', 'plate_x', 'plate_z']]

# Set up the plot
plt.figure(figsize=(8, 6))

# Create scatter plot
sns.scatterplot(data=description_locations, x="plate_x", y="plate_z", hue="description", s=100, alpha=0.3)

# Customize the axes
plt.axvline(x=-0.71, color='gray', linestyle='--')  # left bound of strike zone (17 inches / 2)
plt.axvline(x=0.71, color='gray', linestyle='--')  # right bound of strike zone (17 inches / 2)

# Add labels and legend
plt.title("Scatter Plot of Batting Events Crossing Plate")
plt.xlabel("Horizontal Position (feet)")
plt.ylabel("Vertical Position (feet)")
plt.legend(title="Batting Event")

# Show plot
plt.show()

# %% [markdown]
# ### Create various machine learning models for classifying outcome of swinging bat play (strike or hit into play)

# %%
judge_model_data = mlb_metrics_helpers.batter_model_metrics(judge_specific_stats)
judge_model_data
# Out:
#      pitch_type  release_speed  release_pos_x  release_pos_y  \
# 0            CU           77.0          -2.27          53.95
# 3            FS           86.5          -2.38          53.66
# 5            FF           93.0          -2.42          53.89
# 35           SL           87.2           2.31          54.11
# 37           FF           94.0           2.33          54.09
# ...         ...            ...            ...            ...
# 3102         SL           84.8          -1.81          53.44
# 3108         FF           94.1          -1.29          53.76
# 3114         FF           95.6          -1.88          54.19
# 3117         KC           79.8          -1.84          54.62
# 3126         FC           91.0          -2.12          54.31
#
#       release_spin_rate  spin_axis p_throws  plate_x  plate_z       vx0  \
# 0                2070.0       41.0        R     0.82     1.44  5.213895
# 3                1670.0      238.0        R     0.04     1.70  7.816156
# 5                2269.0      233.0        R    -0.55     3.76  7.629651
# 35               2082.0      170.0        L     0.09     2.22 -4.918468
# 37               2240.0      150.0        L    -0.28     3.72 -8.081169
# ...                 ...        ...      ...      ...      ...       ...
# 3102             2078.0       49.0        R     0.61     1.46  5.207271
# 3108             2208.0      205.0        R     0.50     1.99  6.105346
# 3114             2611.0      212.0        R    -0.21     1.72  6.719506
# 3117             2334.0       29.0        R    -0.52     2.02  1.817991
# 3126             2526.0      180.0        R     0.72     2.09  6.247395
#
#              vy0       vz0         ax         ay         az      description
# 0    -111.910639  0.021591   5.075797  23.467290 -40.612124  swinging_strike
# 3    -125.822604 -3.344875 -11.776428  21.458979 -28.657600  swinging_strike
# 5    -135.143926 -0.724825 -17.391617  32.104993 -18.524160    hit_into_play
# 35   -126.938963 -4.427371  -1.348054  24.203796 -25.082623    hit_into_play
# 37   -136.675580 -4.124875   8.997411  27.747059 -13.121643  swinging_strike
# ...          ...       ...        ...        ...        ...              ...
# 3102 -123.467787 -2.670338   1.731825  22.857826 -33.399100  swinging_strike
# 3108 -136.665543 -9.777313  -9.394336  30.134973 -10.538146    hit_into_play
# 3114 -138.815237 -9.266855 -14.793779  29.907845  -8.027452    hit_into_play
# 3117 -116.170745  0.326995   4.686705  24.469374 -44.671598  swinging_strike
# 3126 -132.423184 -5.839368   3.555157  25.026586 -19.239904  swinging_strike
#
# [4262 rows x 16 columns]

# %%
sklearn_model_types = ["logistic_regression", "random_forest", "gradient_boosting", "hist_gradient_boosting"]
for model_type in sklearn_model_types:
    model, accuracy = mlb_metrics_helpers.tested_batter_model(judge_model_data, model_type)
    print(f"{model_type} accuracy: {accuracy}")
# Out:
# logistic_regression accuracy: 0.639344262295082
# random_forest accuracy: 0.7540983606557377
# gradient_boosting accuracy: 0.765807962529274
# hist_gradient_boosting accuracy: 0.7564402810304449
